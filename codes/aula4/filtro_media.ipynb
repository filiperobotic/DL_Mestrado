# %% [markdown]
# <a href="https://colab.research.google.com/github/filiperobotic/DL_Mestrado/blob/master/codes/aula4/filtro_media.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/filiperobotic/cursoDL.git

# %%
import cv2
import numpy as np 
from matplotlib import pyplot as plt
# %matplotlib inline

image = cv2.imread('cursoDL/imagens/car.png',0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1,1,1, xticks=[], yticks=[])
ax.imshow(image,cmap='gray')
plt.title('Imagem original')
# Out:
# Text(0.5, 1.0, 'Imagem original')

# %%
filtrada = np.zeros((image.shape[0], image.shape[1]))

#TODO - filtro media


fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1,1,1, xticks=[], yticks=[])
ax.imshow(filtrada,cmap='gray')
plt.title('Imagem filtrada')
